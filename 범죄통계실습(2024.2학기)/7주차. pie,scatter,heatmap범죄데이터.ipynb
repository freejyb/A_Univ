# %% [markdown]
# Pie Chart, Scatter Chart, Heatmap,violin plots, box plots

# %% [markdown]
# ## Pie Chart

# %%
# 질적자료(범주형)에 대한 그래프
# 파이 챠트 : 원을 그린후 그 원에 각 계급의 상대도수에 대응하는 면적 또는 부분으로 나눈다.

# 도수(frequency) : 각 범주에 속하는 관측값의 개수 (건수)
# 상대도수(relative frequency) : 도수를 전체 개수로 나눈 비율==> autopct
# 도수분포표(frequency table) : 범주형 자료에서 범주와 그 범주에 대응하는 도수와 상대도수를 나열하는 표

# plt.pie() :  파이 모양의 차트를 표현 가능
# autopct : 각 파이 각각에 문자열을 출력하는 것을 설정

# %%
# 라이브러리 불러오기
import matplotlib.pyplot as plt

# %%
# 아래 리스트 데이터에

x = ['서울', '부산', '인천', '대구']
y = [30, 100, 55, 10]

# ‘%.2f’는 소수점 두번째만 출력하라는 의미
# ‘%%’는 문자 ‘%’를 표현하는 것
# explode :  # explode : 조각내기,   보통 강조할 때 쓰이는 것으로 각 파이를 분리하여 표현하는 정도


plt.pie(y, labels=x, autopct='%.2f%%', explode=(0, 0.1, 0, 0))
plt.title('경찰청별 검거비율')
plt.show()
# Out:
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 52272 (\N{HANGUL SYLLABLE CAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 52397 (\N{HANGUL SYLLABLE CEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 44160 (\N{HANGUL SYLLABLE GEOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\IPython\core\pylabtools.py:134: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 아래 리스트 데이터에 대하여 파이 챠트

x = ['서울', '부산', '인천', '대구']
y = [30, 100, 55, 10]

# ‘%.2f’는 소수점 두번째만 출력하라는 의미
# ‘%%’는 문자 ‘%’를 표현하는 것
# explode :  # explode : 조각내기,   보통 강조할 때 쓰이는 것으로 각 파이를 분리하여 표현하는 정도


plt.pie(y, labels=x, autopct='%.2f%%', explode=(0, 0.1, 0, 0))
plt.title('경찰청별 검거비율')
plt.show()

from matplotlib import font_manager,rc 
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
x = ['서울', '부산', '인천', '대구']
y = [30, 100, 55, 10]

# ‘%.2f’는 소수점 두번째만 출력하라는 의미
# ‘%%’는 문자 ‘%’를 표현하는 것
# explode :  # explode : 조각내기,   보통 강조할 때 쓰이는 것으로 각 파이를 분리하여 표현하는 정도

plt.pie(y, labels=x, autopct='%.f%%', explode=(0, 0.1, 0, 0))
plt.title('경찰청별 검거비율')
plt.show()

# %% [markdown]
# ## 산점도(scatter plot)

# %%
# plt.scatter()를 이용하여 2차원 상에서 점을 차트를 표현 가능
# 두 개의 실수 데이터를 상관관계를 한눈에 볼 수 있다.

# plt.scatter() 에서 점의 반지름을 설정 가능 
# --> 3차원의 데이터 형식을 표현 :  ‘Bubble Chart’

# %%
import matplotlib.pyplot as plt

# %%
 
plt.scatter(['서울', '부산', '대구', '인천', '제주', '수원'], [10, 20, 30, 45, 55, 85])
plt.title('scatter')
plt.xlabel('경찰청')
plt.ylabel('사건발생')
plt.show()

# %%
import matplotlib.pyplot as plt
 
plt.scatter(['서울', '부산', '대구', '인천', '제주', '수원'], [10, 20, 30, 45, 55, 85])
plt.title('scatter')
plt.xlabel('경찰청')
plt.ylabel('사건발생')
    
plt.grid(True)  # 격자(그물망)
plt.show()

# %%
# 색깔 지정 , 
import matplotlib.pyplot as plt
 
plt.scatter(['서울', '부산', '대구', '인천', '제주', '수원'], [10, 20, 30, 45, 55, 85])
plt.title('scatter')
plt.xlabel('경찰청')
plt.ylabel('사건발생')

plt.scatter(x,y, c='red')
plt.grid(True)  # 그물망
plt.show()

# %% [markdown]
# https://plotly.com/python/plotly-express/
# ###### plotly.express모듈 (별칭 px)

# %%
# !pip install plotly.express
# Out:
# Requirement already satisfied: plotly.express in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (2.2.2)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (5.14.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (0.14.2)
# Requirement already satisfied: scipy>=0.18 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (1.13.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (0.5.6)
# Requirement already satisfied: numpy>=1.11 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly.express) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.20.0->plotly.express) (2021.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.20.0->plotly.express) (2022.7)
# Requirement already satisfied: six in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly>=4.1.0->plotly.express) (8.0.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Error parsing dependencies of ipykernel: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     matplotlib-inline (<0.2.0appnope,>=0.1.0) ; platform_system == "Darwin"
#                       ~~~~~~~~^
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages)
# Requirement already satisfied: packaging in c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages (from plotly>=4.1.0->plotly.express) (24.1)

# %%
#pip install --upgrade pandas

# %% [markdown]
# ## ColorMap, heatmap

# %%
# plt.imshow()를 이용하면 행과 열로 표현된 2D 데이터를 각 수치 정도에 따라 색으로 표현 

# 상관계수를 시각적으로 보여 줄 때 사용

# %%
# 데이터 구성
import plotly.express as px

fig = px.imshow([[10, 20, 30],
                 [20, 1, 60],
                 [30, 60, 20]])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/3750217940.py in <module>
#       1 # 데이터 구성
# ----> 2 import plotly.express as px
#       3
#       4 fig = px.imshow([[10, 20, 30],
#       5                  [20, 1, 60],
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\plotly\express\__init__.py in <module>
#      13     )
#      14
# ---> 15 from ._imshow import imshow
#      16 from ._chart_types import (  # noqa: F401
#      17     scatter,
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\plotly\express\_imshow.py in <module>
#       9
#      10 try:
# ---> 11     import xarray
#      12
#      13     xarray_imported = True
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\xarray\__init__.py in <module>
# ----> 1 from . import testing, tutorial, ufuncs
#       2 from .backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#       5     open_dataarray,
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\xarray\testing.py in <module>
#       6 import numpy as np
#       7
# ----> 8 from xarray.core import duck_array_ops, formatting, utils
#       9 from xarray.core.dataarray import DataArray
#      10 from xarray.core.dataset import Dataset
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\xarray\core\duck_array_ops.py in <module>
#      22 from numpy import where as _where
#      23
# ---> 24 from . import dask_array_compat, dask_array_ops, dtypes, npcompat, nputils
#      25 from .nputils import nanfirst, nanlast
#      26 from .pycompat import (
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\xarray\core\dask_array_ops.py in <module>
# ----> 1 from . import dtypes, nputils
#       2
#       3
#       4 def dask_rolling_wrapper(moving_func, a, window, min_count=None, axis=-1):
#       5     """Wrapper to apply bottleneck moving window funcs on dask arrays"""
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\xarray\core\dtypes.py in <module>
#      39     {np.number, np.character},  # numpy promotes to character
#      40     {np.bool_, np.character},  # numpy promotes to character
# ---> 41     {np.bytes_, np.unicode_},  # numpy promotes to unicode
#      42 ]
#      43
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     424
#     425         if attr in __expired_attributes__:
# --> 426             raise AttributeError(
#     427                 f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     428                 f"{__expired_attributes__[attr]}"
#
# AttributeError: `np.unicode_` was removed in the NumPy 2.0 release. Use `np.str_` instead.

# %%
# 각 위치마다 색깔 표현해주기
import plotly.express as px
import numpy as np
img_rgb = np.array([[[255, 0, 0], [0, 255, 0], [0, 0, 255]],
                    [[0, 255, 0], [0, 0, 255], [255, 0, 0]]
                   ], dtype=np.uint8)
fig = px.imshow(img_rgb)
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# 상관계수 분포 확인을 위한 데이터 구성
columns = ['X' + str(x).zfill(2) for x in range(10)]
 
data = {}
for k in columns:
    data[k] = [0]*20
 
map_df = pd.DataFrame(data)
map_df.index = ['Y' + str(x).zfill(2) for x in range(20)]
 
for i in range(map_df.shape[0]):
    for j in range(map_df.shape[1]):
        map_df.iloc[i,j] = np.random.randn(1)

# %%
fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
plt.pcolor(map_df.values) ## matplotlib에서 히트맵을 그려주기 위하여 pcolor 함수 이용
plt.xticks(range(len(map_df.columns)),map_df.columns) ## x축 눈금 생성
plt.yticks(range(len(map_df.index)), map_df.index) ## y축 눈금 생성
 
plt.colorbar()  # Heat Map에 pcolor 함수와 함께 컬러바를 표시해야 함
plt.show()

# %%
# Seaborn을 이용하여 Heatmap 그리기
# heatmap 함수에 2차원 numpy.array 또는 pandas.DataFrame을 인자로 넣어주시면 됩니다

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')

# 상관계수 그래프 만들기
sns.heatmap(map_df)
 
plt.show()

# %%
## 데이터 생성데이터 생성
np.random.seed(5)
columns = ['X' + str(x).zfill(2) for x in range(10)]
 
data = {}
for k in columns:
    data[k] = [0]*20
 
map_df = pd.DataFrame(data)
map_df.index = ['Y' + str(x).zfill(2) for x in range(20)]
 
for i in range(map_df.shape[0]):
    for j in range(map_df.shape[1]):
        map_df.iloc[i,j] = np.random.randn(1)

# %%
## Matplotlib
fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
plt.pcolor(map_df.values,cmap='Reds')
plt.xticks(range(len(map_df.columns)),map_df.columns) ## x축 눈금 생성
plt.yticks(range(len(map_df.index)), map_df.index) ## y축 눈금 생성
 
plt.colorbar()
plt.show()

# %% [markdown]
# ## violin plots

# %%
# 일변량, 연속형 데이터의 분포를 설명하기 위해 사용되는 그래프
# 대부분의 내용이 박스 플롯 정보 포함

# %%
# 일변량(1개) 연속형 데이터 :  히스토그램(Histogram) , 커널 밀도 곡선(Kernel Density Curve) 
# 박스 그래프(Box Plot) ,# 바이올린 그래프(Violin Plot)

#일변량(1개) 범주형 데이터 : 막대 그래프(Bar Chart),원 그래프(Pie Chart)

# 다변량(2개 이상)연속형 데이터  :  선 그래프(Line Chart), 산점도(Scatter)

# 다변량 범주형 데이터 : 히트맵(Heatmap)
#seaborn 패키지에 내장되어 있는 tips 라는 DataFrame 을 사용

# %%
import plotly.express as px
df = px.data.tips()
fig = px.violin(df, y="tip", x="smoker", color="sex", box=True, points="all", hover_data=df.columns)
fig.show()

# %% [markdown]
# ## box_plot

# %%
# 분포 형태, 퍼짐정도, 이상치 여부 등을 시각화하고, 하나의 그룹 혹은 여러개의 그룹 간 비교하는데 유용
# 최소값(min), 제 1사분위수(Q1), 중앙값(Q2, median), 제 3사분위수(Q3), 최대값(max) 의 요약통계량을 계산하는 것에서 시작

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 6]
# %matplotlib inline

# %%
# seaborn 패키지에 내장되어 있는 'tips'  데이터셋 사용

# %%
# loading 'tips' dataset

tips = sns.load_dataset('tips')

# %%
# 행과 열 개수 확인

tips.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/203255629.py in <module>
#       1 # 행과 열 개수 확인
#       2
# ----> 3 tips.shape
#
# NameError: name 'tips' is not defined

# %%
tips.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/3329484729.py in <module>
# ----> 1 tips.head(20)
#
# NameError: name 'tips' is not defined

# %%
tips.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/510540819.py in <module>
# ----> 1 tips.tail()
#
# NameError: name 'tips' is not defined

# %%
tips.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/821099323.py in <module>
# ----> 1 tips.tail(10)
#
# NameError: name 'tips' is not defined

# %%
# 성별과 날짜로 묶기

tips.groupby(['sex', 'day']).size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/4022611781.py in <module>
#       1 # 성별과 날짜로 묶기
#       2
# ----> 3 tips.groupby(['sex', 'day']).size()
#
# NameError: name 'tips' is not defined

# %%
# boxplot() 함수를 사용
# default 세팅으로 상자 그림

plt.boxplot(tips['tip'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/1238822770.py in <module>
#       2 # default 세팅으로 상자 그림
#       3
# ----> 4 plt.boxplot(tips['tip'])
#       5 plt.show()
#
# NameError: name 'tips' is not defined

# %%
# 상자 그림의 이상치(outlier) 모양과 색깔, 제목(title), X축 이름(X label)을 설정
# outlier symbol, title, xlabel

plt.boxplot(tips['tip'], sym="bo")
plt.title('box of tip')
plt.xticks([1], ['tip'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/2009218501.py in <module>
#       2 # outlier symbol, title, xlabel
#       3
# ----> 4 plt.boxplot(tips['tip'], sym="bo")
#       5 plt.title('box of tip')
#       6 plt.xticks([1], ['tip'])
#
# NameError: name 'tips' is not defined

# %%
# 한 개의 축에 여러 개의 연속형 변수(total_bill, tip)에 대한 여러 개의 상자 그림

fig, ax = plt.subplots()
ax.boxplot([tips['total_bill'], tips['tip']], sym="b*")
plt.title('Multiple box plots of tips on one Axes')
plt.xticks([1, 2],['total_bill', 'tip'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/3076491084.py in <module>
#       2
#       3 fig, ax = plt.subplots()
# ----> 4 ax.boxplot([tips['total_bill'], tips['tip']], sym="b*")
#       5 plt.title('Multiple box plots of tips on one Axes')
#       6 plt.xticks([1, 2],['total_bill', 'tip'])
#
# NameError: name 'tips' is not defined

# %%
 # seaborn 으로 여러개 그룹에 대한 상자 그림 그리기

# %%
# 요일(day) 그룹별러 팁(tip)에 대한 상자 그림 비교

import seaborn as sns
sns.boxplot(x="day",y="tip",data=tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/4031768851.py in <module>
#       1 # 요일(day) 그룹별러 팁(tip)에 대한 상자 그림 비교
#       2
# ----> 3 import seaborn as sns
#       4 sns.boxplot(x="day",y="tip",data=tips)
#       5 plt.show()
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\seaborn\__init__.py in <module>
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\seaborn\matrix.py in <module>
#      11 from scipy.cluster import hierarchy
#      12
# ---> 13 from . import cm
#      14 from .axisgrid import Grid
#      15 from .utils import (despine, axis_ticklabels_overlap, relative_luminance,
#
# c:\users\jyb\appdata\local\programs\python\python39\lib\site-packages\seaborn\cm.py in <module>
#    1580     locals()[_name + "_r"] = _cmap_r
#    1581
# -> 1582     mpl_cm.register_cmap(_name, _cmap)
#    1583     mpl_cm.register_cmap(_name + "_r", _cmap_r)
#    1584
#
# AttributeError: module 'matplotlib.cm' has no attribute 'register_cmap'

# %%
# pandas의 DataFrame에 df.boxplot() 함수를 사용하여 상자 그림

tips.boxplot(column=["tip"], by=["day", "sex"])
plt.show()

# %%
# 라이브러리 불러오기

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy as sp


# 한글폰트 출력 가능 코드
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 데이터 설명: 케글에 있는 Chicago Crime(2001~현재) 데이터에서 2022년에 일어난 데이터
#
# ### https://www.kaggle.com/datasets/chicago/chicago-crime

# %%
# 깃허브 : 파일명 : 범죄데이터.csv

df = pd.read_csv("범죄데이터.csv",index_col=0)
df

# %%
# 파일데이터 확인

df.info()

# %%
# ### 1. 컬럼 설명

# 1. 'ID': 범죄 사건을 고유하게 식별하는 식별자(ID)입니다. 각각의 범죄 사건은 고유한 ID를 가지고 있습니다.

# 2. 'Case Number': 해당 사건에 대한 보고서 번호 또는 사건 번호를 나타냅니다. 범죄 사건마다 고유한 케이스 번호가 부여됩니다.

# 3. 'Date': 범죄가 발생한 날짜와 시간 정보를 나타내는 컬럼입니다. 사건이 발생한 정확한 날짜와 시간이 기록됩니다.

# 4. 'Block': 범죄 발생 장소의 도로 블록(일반적으로 주소의 일부)을 설명하는 컬럼입니다.

# 5. 'IUCR': 'Illinois Uniform Crime Reporting'의 약자로, 일리노이 주의 표준 범죄 분류 코드를 나타내는 컬럼입니다. 범죄 유형을 구분하는데 사용됩니다.

# 6. 'Primary Type': 주요 범죄 유형을 나타내는 컬럼입니다. 각각의 사건에 대해 주요 범죄 유형이 지정됩니다.

# 7. 'Description': 범죄의 세부적인 설명을 담고 있는 컬럼입니다. 'Primary Type'과 함께 범죄에 대한 자세한 정보를 제공합니다.

# 8. 'Location Description': 범죄가 발생한 장소를 설명하는 컬럼입니다. 주차장, 가정, 상점 등 특정 장소 유형을 나타낼 수 있습니다.

# 9. 'Arrest': 범죄가 발생한 후 용의자가 체포되었는지 여부를 나타내는 컬럼입니다. 'True' 또는 'False'로 표시됩니다.

# 10. 'Domestic': 범죄가 가정 내에서 발생했는지 여부를 나타내는 컬럼입니다. 'True' 또는 'False'로 표시됩니다.

# 11. 'Beat': 아틀란타 시에서 사용되는 행정적인 지역 구분 단위를 나타내는 컬럼입니다. 범죄 관리와 분석을 위해 사용됩니다.

# 12. 'District': 경찰 구역을 나타내는 컬럼입니다. 'Beat'와 유사한 목적으로 사용됩니다.

# 13. 'Ward': 도시에서 특정 지역을 의미하는 행정 구역을 나타내는 컬럼입니다.

# 14. 'Community Area': 도시 내 특정 지역을 의미하는 행정 구역을 나타내는 컬럼입니다.

# 15. 'FBI Code': FBI(Federal Bureau of Investigation)에서 사용하는 범죄 분류 코드를 나타내는 컬럼입니다.

# 16. 'X Coordinate' 및 'Y Coordinate': 범죄가 발생한 위치의 좌표 정보를 나타내는 컬럼들입니다.

# 17. 'Year': 범죄가 발생한 연도를 나타내는 컬럼입니다.

# 18. 'Updated On': 데이터가 업데이트된 날짜와 시간 정보를 나타내는 컬럼입니다.

# 19. 'Latitude'와 'Longitude': 범죄 발생 위치의 위도와 경도 좌표 정보를 나타내는 컬럼들입니다.

# 20. 'Location': 범죄 발생 위치의 전체적인 좌표 정보를 담고 있는 컬럼입니다. 'Latitude'와 'Longitude'와 같은 정보를 포함합니다.

# %%
# 컬럼명 :  한글 로 변경 
df.columns =  ['사건 번호', '날짜','블록','IUCR','범죄 유형','설명','위치 설명','검거 여부','가정 내 범죄','경찰서 순번','지구','구','지역 번호','FBI 코드','X 좌표','Y 좌표','년도','업데이트 일자','위도','경도','위치']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/2427937015.py in <module>
#       1 # 컬럼명 :  한글 로 변경
# ----> 2 df.columns =  ['사건 번호', '날짜','블록','IUCR','범죄 유형','설명','위치 설명','검거 여부','가정 내 범죄','경찰서 순번','지구','구','지역 번호','FBI 코드','X 좌표','Y 좌표','년도','업데이트 일자','위도','경도','위치']
#
# NameError: name 'df' is not defined

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/2991697616.py in <module>
# ----> 1 df.reset_index(inplace=True,drop=True)
#       2 df
#
# NameError: name 'df' is not defined

# %%
# 데이터 탐색하기

# %%
df["범죄 유형"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/2844889638.py in <module>
# ----> 1 df["범죄 유형"].unique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 범죄 유형 별 빈도수 시각화

# %%
plt.figure(figsize=(10, 10))  # 그래프 크기 지정 (선택사항)
colors = plt.cm.viridis(np.linspace(0, 1, 20))
plt.barh(df["범죄 유형"].value_counts()[:20].index,df["범죄 유형"].value_counts()[:20].values, color=colors )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
plt.xlabel("범죄 유형")  # x축 라벨 지정
plt.ylabel('빈도수')  # y축 라벨 지정
plt.title('컬럼 데이터 분포')  # 그래프 제목 지정 (선택사항)
plt.show()  # 그래프 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/1333966917.py in <module>
#       1 plt.figure(figsize=(10, 10))  # 그래프 크기 지정 (선택사항)
# ----> 2 colors = plt.cm.viridis(np.linspace(0, 1, 20))
#       3 plt.barh(df["범죄 유형"].value_counts()[:20].index,df["범죄 유형"].value_counts()[:20].values, color=colors )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
#       4 plt.xlabel("범죄 유형")  # x축 라벨 지정
#       5 plt.ylabel('빈도수')  # y축 라벨 지정
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 범죄 유형 별 빈도수 시각화

# %%
# 데이터프레임 생성

df["날짜"] = pd.to_datetime(df["날짜"])  # 날짜와 시간 형식으로 변환
df['일자'] = df["날짜"].dt.date  # 날짜만 추출

# 범죄 유형 별 빈도수 시각화
date_distribution = df['일자'].value_counts().sort_index()

# 시계열 그래프 시각화
plt.figure(figsize=(12, 6))
date_distribution.plot(marker='o')
plt.xlabel('날짜')
plt.ylabel('빈도')
plt.title('시간 분포 시계열 그래프')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/1661503711.py in <module>
#       1 # 데이터프레임 생성
#       2
# ----> 3 df["날짜"] = pd.to_datetime(df["날짜"])  # 날짜와 시간 형식으로 변환
#       4 df['일자'] = df["날짜"].dt.date  # 날짜만 추출
#       5
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### 용의자 체포 여부 시각화

# %%
# 용의자 체포 여부 시각화
plt.figure(figsize=(10, 6))  # 그래프 크기 지정 (선택사항)
plt.bar(df["검거 여부"].value_counts().index,df["검거 여부"].value_counts().values )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
plt.xlabel("검거 여부")  # x축 라벨 지정
plt.ylabel('빈도수')  # y축 라벨 지정
plt.xticks([0, 1])
plt.title('컬럼 데이터 분포')  # 그래프 제목 지정 (선택사항)
plt.show()  # 그래프 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/538064679.py in <module>
#       1 # 용의자 체포 여부 시각화
#       2 plt.figure(figsize=(10, 6))  # 그래프 크기 지정 (선택사항)
# ----> 3 plt.bar(df["검거 여부"].value_counts().index,df["검거 여부"].value_counts().values )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
#       4 plt.xlabel("검거 여부")  # x축 라벨 지정
#       5 plt.ylabel('빈도수')  # y축 라벨 지정
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 범죄가 가정내 발생여부 확인

# %%
# 범죄가 가정내 발생여부 확인
plt.figure(figsize=(10, 6))  # 그래프 크기 지정 (선택사항)
plt.bar(df["가정 내 범죄"].value_counts().index,df["가정 내 범죄"].value_counts().values )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
plt.xlabel("가정 내 범죄")  # x축 라벨 지정
plt.ylabel('빈도수')  # y축 라벨 지정
plt.xticks([0, 1])
plt.title('컬럼 데이터 분포')  # 그래프 제목 지정 (선택사항)
plt.show()  # 그래프 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/1181124628.py in <module>
#       1 # 범죄가 가정내 발생여부 확인
#       2 plt.figure(figsize=(10, 6))  # 그래프 크기 지정 (선택사항)
# ----> 3 plt.bar(df["가정 내 범죄"].value_counts().index,df["가정 내 범죄"].value_counts().values )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
#       4 plt.xlabel("가정 내 범죄")  # x축 라벨 지정
#       5 plt.ylabel('빈도수')  # y축 라벨 지정
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 범죄 위치 별 빈도수 시각화

# %%
# 범죄 위치 별 빈도수 시각화
plt.figure(figsize=(10, 10))  # 그래프 크기 지정 (선택사항)
colors = plt.cm.plasma(np.linspace(0, 1, 20))
plt.barh(df["위치 설명"].value_counts()[:20].index,df["위치 설명"].value_counts()[:20].values,color=colors )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
plt.xlabel("위치 설명")  # x축 라벨 지정
plt.ylabel('빈도수')  # y축 라벨 지정
plt.title('컬럼 데이터 분포')  # 그래프 제목 지정 (선택사항)
plt.show()  # 그래프 출력
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/2746411689.py in <module>
#       1 # 범죄 위치 별 빈도수 시각화
#       2 plt.figure(figsize=(10, 10))  # 그래프 크기 지정 (선택사항)
# ----> 3 colors = plt.cm.plasma(np.linspace(0, 1, 20))
#       4 plt.barh(df["위치 설명"].value_counts()[:20].index,df["위치 설명"].value_counts()[:20].values,color=colors )  # 히스토그램으로 시각화 (다른 종류의 그래프도 가능)
#       5 plt.xlabel("위치 설명")  # x축 라벨 지정
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 사건발생 지도 시각화

# %%
import folium

# 지도 생성
map_center = [41.850, -87.650]  # 서울의 위도와 경도
map_osm = folium.Map(location=map_center, zoom_start=13)
locations = []
# 위치 데이터 리스트 (예시)
for i in df.index:

    a =    {'name': i, 'lat': df.loc[i,"위도"] ,'lon': df.loc[i,"경도"]},
    locations.append(a)
    # 추가적인 위치 데이터를 원하는 만큼 리스트에 추가할 수 있습니다.
# 마커 추가
for i in locations[:100]:
    location = i[0]
    marker = folium.Marker(
        location=[location['lat'], location['lon']],
        popup=location['name']
    )
    marker.add_to(map_osm)

# 지도를 HTML 파일로 저장
map_osm.save("map.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9496/1915539148.py in <module>
#       6 locations = []
#       7 # 위치 데이터 리스트 (예시)
# ----> 8 for i in df.index:
#       9
#      10     a =    {'name': i, 'lat': df.loc[i,"위도"] ,'lon': df.loc[i,"경도"]},
#
# NameError: name 'df' is not defined

# %%
# 장소 시각화 
map_osm
