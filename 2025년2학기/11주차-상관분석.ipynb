# %% [markdown]
# 상관분석

# %% [markdown]
# # 상관(관계) 분석 이해

# %% [markdown]
# ## 상관분석(Correlation Analysis)이란?

# %%
# 상관분석은 두 변수 간의 관계를 측정하는 통계적 방법입니다. 
# 이를 통해 두 변수 사이에 어떤 관계가 있는지, 그 관계가 긍정적인지(정적 상관) 또는 부정적인지(부적 상관)를 알 수 있습니다.

# %% [markdown]
# ## 상관계수

# %%
# 상관계수는 상관분석의 결과를 수치로 나타낸 것으로, 두 변수 간의 관계의 강도와 방향을 나타냅니다. 
# 상관계수의 범위는 -1에서 1 사이입니다.

# 피어슨 (연속형변수 간) 스피어만, 캔달 (명목형변수 간)

# %%
# 피어슨(Pearson), 스피어만(Spearman), 캔달(Tau) 상관계수는 두 변수 간의 관계를 측정하는 대표적인 방법
# 각각의 특성과 사용 목적에 따라 다르게 적용됩니다. 
# 이 세 가지 상관계수는 본질적으로 두 변수 간의 선형적 혹은 비선형적 관계의 강도를 나타내지만, 
# 그 계산 방식과 해석에 있어서 중요한 차이가 있습니다.

# %% [markdown]
# ### 피어슨 상관계수 (Pearson Correlation Coefficient)

# %%
# 특징: 피어슨 상관계수는 두 변수 간의 선형 관계의 강도를 측정합니다. 
# 데이터가 연속적이며 정규분포를 따르고, 선형적 관계가 있다고 가정할 때 사용됩니다.

# 계산 방식: 두 변수의 공분산을 각 변수의 표준편차로 곱으로 나눈 값이다.
# 값의 범위 : -1에서 1 사이의 값을 가집니다. -1과 1에 가까울수록 상관관계가 높다고 말할 수 있습니다.
# +1: 완벽한 양의 선형 관계
# 0: 선형 관계 없음
# -1: 완벽한 음의 선형 관계

# 전제 조건(가정)
# 데이터는 연속적이고, 정규성을 만족해야 하며, 선형 관계가 존재해야 함.

# 이상치(Outliers)에 매우 민감함.

# 적용 예: 두 변수 간에 선형적인 관계가 강하게 예상되는 경우, 예를 들어 키와 체중 간의 관계를 분석할 때 유용합니다.

# %% [markdown]
# ### 스피어만 상관계수 (Spearman's Rank Correlation Coefficient)

# %%
# 특징: 스피어만 상관계수는 두 변수 간의 비선형 관계를 포함한 단조 관계(monotonic relationship)의 강도를 측정합니다. 
# 피어슨 상관계수와 달리, 스피어만 상관계수는 순위를 사용하여 계산되기 때문에, 두 변수의 관계가 반드시 선형적일 필요는 없습니다.

# 계산 방식: 원 데이터 대신 각 변수의 순위를 사용하여 계산하며, -1에서 1 사이의 값을 가집니다.
# +1: 완벽한 단조 증가 관계
# 0: 단조 관계 없음
# -1: 완벽한 단조 감소 관계

# 전제 조건:
# 데이터가 순위를 나타낼 수 있어야 하며, 비선형 단조 관계를 가정할 수 있음.

# 이상치에 덜 민감함.
# 적용 예: 예를 들어 학생들의 시험 성적 순위와 학습 시간 순위 간의 관계를 분석할 때, 선형 관계가 아닌 단조적 관계를 측정할 수 있습니다.

# %% [markdown]
# ### 캔달의 타우 상관계수 (Kendall's Tau)

# %%
# 특징: 캔달의 타우 상관계수는 두 변수 간의 순위 데이터에서 일치 및 불일치 쌍의 수를 기반으로 상관 관계를 측정합니다. 

# 캔달의 타우는 스피어만 상관계수와 비슷하게 순위 데이터를 사용하지만, 계산 방식이 다릅니다.

# 계산 방식: 두 변수의 순위 간 일치(concordant)와 불일치(discordant) 쌍을 비교하여 상관계수를 계산합니다. 
# 값의 범위 :  -1에서 1까지입니다.
# +1: 완벽한 순위 일치
# 0: 순위에 무작위적 관계
# -1: 완벽한 순위 불일치

# 전제 조건:
# 순위 데이터에 기반하며, 순위 일관성을 강조.

# 이상치에 더 강건하며, 작은 표본에서도 적합하게 작동합니다.
# 적용 예: 사회 과학 연구에서 설문 조사나 등급 평가 등에서 순위를 비교할 때 유용합니다.

# %% [markdown]
# ## 데이터 준비

# %%
# 라이브러리 불러오기

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy as sp


# 한글폰트 출력 가능 코드
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# 아래는 각 동별 교조소 수용자 수용성적 list 데이터

A동=[90,90,80,70]
B동=[65,85,100,90]
C동=[80,60,70,90]

# %%
A동
# Out:
# [90, 90, 80, 70]

# %%
B동
# Out:
# [65, 85, 100, 90]

# %%
# 파이썬 list를 DataFrame으로 만드는 방법

# DataFrame  Row, Column, Series 들로 구성 : 7주차 pandas 수업 참고할 것 ·

# %%
score = pd.DataFrame({"A동":[90,90,80,70], "B동":[65,85,100,90], "C동":[80,60,70,90]})

# %%
score
# Out:
#    A동   B동  C동
# 0  90   65  80
# 1  90   85  60
# 2  80  100  70
# 3  70   90  90

# %% [markdown]
# ## 상관계수(Correlation Coefficient) 구하기

# %%
# 상관계수 (Correlation  Coefficient) 계산 
# 두 변수의 공분산 값을 각각의 표준편차의 곱으로 나눈 값으로,  공분산 값을 표준화한 개념으로 이해하면 됩니다.
# 공분산 : 편차와 편차의 곱에 기대치

# %%
# 변수명.corr()
score.corr()
# Out:
#           A동        B동        C동
# A동  1.000000 -0.591312 -0.674200
# B동 -0.591312  1.000000 -0.175412
# C동 -0.674200 -0.175412  1.000000

# %%
# 결과 해석
# A와 B ; 음(-)의 상관관계
# A와 C ; 음(-)의 상관관계
# B와 C ; 음(-)의 상관관계

# %% [markdown]
# ## 히트맵으로 보기

# %%
# 히트맵(Heatmap)은 데이터를 시각적으로 표현하는 도구 중 하나로, 데이터의 크기나 강도를 색상으로 나타내는 그래프입니다. 
# 주로 상관행렬을 시각화할 때 사용되며, 변수 간의 상관관계를 직관적으로 파악할 수 있게 해줍니다.

# 히트맵의 주요 특징
# 색상으로 값 표현: 각 셀의 값에 따라 색상이 달라집니다. 
# 일반적으로 짙은 색은 큰 값(높은 상관), 옅은 색은 작은 값(낮은 상관)을 의미합니다. 
# 색상의 스케일은 사용자가 선택할 수 있지만, 보통 연속적인 스케일(예: 파란색에서 빨간색으로 변화)을 사용합니다.

# 행렬 형태: 히트맵은 보통 행과 열로 구성된 표(행렬)의 형태로 데이터 간의 관계를 표현합니다. 
# 상관관계를 나타내는 히트맵에서는 각 변수들 사이의 상관계수가 색상으로 표시됩니다.

# %%
sns.heatmap(score.corr())
# Out:
# <Axes: >

# %%
# 옵션 주기 : 상관계수 숫자 추가하기

# annot=True를 설정하면, 히트맵의 각 셀에 그 값이 숫자로 표시됩니다. 
# 예를 들어, 상관행렬을 시각화한 히트맵에서는 상관계수 값이 각 셀 내부에 적히게 됩니다.
# 이 옵션을 사용하지 않으면 셀의 색상만으로 값을 표현하며, 숫자는 표시되지 않습니다.

sns.heatmap(score.corr(), annot=True)
# Out:
# <Axes: >

# %%
# 옵션 주기 : 제목 달기
sns.heatmap(score.corr(), annot=True)
plt.title('수용동별 평가 점수')
# Out:
# Text(0.5, 1.0, '수용동별 평가 점수')

# %%
# 옵션 주기 : x축 글자 변형
sns.heatmap(score.corr(), annot=True)
plt.title('수용동별 평가 점수')
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5]),
#  [Text(0.5, 0, 'A동'), Text(1.5, 0, 'B동'), Text(2.5, 0, 'C동')])

# %%
# 옵션 주기 : x축, t축 글자 변형
sns.heatmap(score.corr(), annot=True)
plt.title('수용자 평가 점수')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5]),
#  [Text(0, 0.5, 'A동'), Text(0, 1.5, 'B동'), Text(0, 2.5, 'C동')])

# %% [markdown]
# # 피어슨(Pearson) 상관계수 구하기

# %%
# 상관계수 구하는 방법 : 데이터프레임의 이름.corr(method='pearson')      # Correlation  Coefficient (상관계수)

# %%
score_corr = score.corr(method = 'pearson')

# %%
score_corr
# Out:
#           A동        B동        C동
# A동  1.000000 -0.591312 -0.674200
# B동 -0.591312  1.000000 -0.175412
# C동 -0.674200 -0.175412  1.000000

# %%
# 결과 해석

# %%
# A 동수용자 성적과 B 수용자 음(-) -0.591312
# A 동수용자 성적과 C 수용자 음(-) -0.674200
# B 동수용자 성적과 C 수용자 음(-) -0.175412 --> 0에 가깝다.

# %% [markdown]
# ## 히트맵 그리기

# %%
# 데이터프레임에서 .values를 하게되면 데이터프레임의 각 행이 마치 리스트 형태로 변환되어서 출력 
# --> 차트를 그릴 때, 입력으로 사용할 것

# %%
score_corr.values
# Out:
# array([[ 1.        , -0.5913124 , -0.67419986],
#        [-0.5913124 ,  1.        , -0.1754116 ],
#        [-0.67419986, -0.1754116 ,  1.        ]])

# %%
# 차트에 이름을 입력하기
# column_names라는 리스트를 만든다.

# %%
import seaborn as sns


# 한글폰트 출력 가능 코드
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
column_names = ['A', 'B', 'C']

# %%
# 레이블의 폰트 사이즈를 조정
sns.set(font_scale=2.0)


score_corr_heatmap = sns.heatmap(score_corr.values, # 수용자 점수 데이터
                          cbar = False, # 오른쪽 컬러 막대 출력 여부
                           annot = True, # 차트에 숫자를 보여줄 것인지 여부
                          annot_kws={'size' : 20}, # 숫자 출력 시 숫자 크기 조절
                           fmt = '.2f', # 숫자의 출력 소수점자리 개수 조절
                           square = 'True', # 차트를 정사각형으로 할 것인지
                          yticklabels=column_names, # y축에 컬럼명 출력
                          xticklabels=column_names) # x축에 컬럼명 출력
plt.tight_layout()
plt.show()

# %%
#  오른쪽 컬러 막대 출력 여부 변경 사례 
sns.set(font_scale=2.0)

test_heatmap = sns.heatmap(score_corr.values, # 수용자 점수 데이터
                          cbar = True, # 오른쪽 컬러 막대 출력 여부
                           annot = True, # 차트에 숫자를 보여줄 것인지 여부
                          annot_kws={'size' : 20}, # 숫자 출력 시 숫자 크기 조절
                           fmt = '.2f', # 숫자의 출력 소수점자리 개수 조절
                           square = 'True', # 차트를 정사각형으로 할 것인지
                          yticklabels=column_names, # y축에 컬럼명 출력
                          xticklabels=column_names) # x축에 컬럼명 출력
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 산점도(scatter)로 살펴보기

# %%
# 아래 리스트 A 동과 B동
import pandas as pd

A=[90,90,80,70]
B=[65,85,100,90]

# %%
# DataFrame 만들기

score = pd.DataFrame({'A': A, 'B': B})

# %%
# 한글폰트 출력 가능 코드
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
A=[90,90,80,70]
B=[65,85,100,90]

# %%
# 산점도(scatter) 그리기

import matplotlib.pylab as plt  # 라이브러리 불러오기 

plt.scatter( score['A'],score['B'], label = "data")

plt.legend(loc = "best")
plt.xlabel('A수용동 성적')
plt.ylabel('B수용동 성적')
plt.show()

# %%
E=[10,20,30,40,40, 60, 70, 80, 90, 100, 110, 111]
F=[5,15,19,25, 35, 45, 55, 68, 77, 80, 90, 98]

# %%
score1 = pd.DataFrame({'E': E, 'F': F})

# %%
score1
# Out:
#       E   F
# 0    10   5
# 1    20  15
# 2    30  19
# 3    40  25
# 4    40  35
# 5    60  45
# 6    70  55
# 7    80  68
# 8    90  77
# 9   100  80
# 10  110  90
# 11  111  98

# %%
# 산점도(scatter) 그리기

import matplotlib.pylab as plt  # 라이브러리 불러오기 

plt.scatter( score1['E'],score1['F'], label = "비교표")

plt.legend(loc = "best")
plt.xlabel('E동 수용성적')
plt.ylabel('F동 수용성적')
plt.show()

# %%
# 결과 : 강한 양(+)의 상관관계로 보임

# %%
# 리스트를 데이터 프레임으로 만들기

score1 = pd.DataFrame({"E":[10,20,30,40,40, 60, 70, 80, 90, 100, 110, 111],"F":[5,15,19,25, 35, 45, 55, 68, 77, 80, 90,98]})
score1
# Out:
#       E   F
# 0    10   5
# 1    20  15
# 2    30  19
# 3    40  25
# 4    40  35
# 5    60  45
# 6    70  55
# 7    80  68
# 8    90  77
# 9   100  80
# 10  110  90
# 11  111  98

# %%
score1_corr = score1.corr(method = 'pearson')

# %%
score1_corr
# Out:
#           E         F
# E  1.000000  0.994167
# F  0.994167  1.000000

# %%
# 결과 해석 

# : 상관계수 범위 -1~ 1 ==>  E와 F 상관계수 0.994167

# %% [markdown]
# # 스피어만 상관계수

# %%
score_corr1 = score.corr(method = 'spearman')

# %%
score_corr1
# Out:
#           A동        B동        C동
# A동  1.000000 -0.737865 -0.632456
# B동 -0.737865  1.000000  0.000000
# C동 -0.632456  0.000000  1.000000

# %% [markdown]
# # 실습 (범죄데이터 불러오기) 1

# %%
# ("crime_list.csv")

# %%
# 판다스 부분에서 했었던 데이터 불러오기
# 앞에서 실습한 파일 : crime_list.csv 사용

crime_list = pd.read_csv("crime_list.csv")

crime_list
# Out:
#     Unnamed: 0          날짜   ID  나이  성별      소득  범죄건수
# 0            0  2022-11-24    1  71  여성  141440     5
# 1            1  2022-02-27    2  67  남성  122769     4
# 2            2  2022-01-13    3  67  남성  122908     2
# 3            3  2022-05-21    4  21  여성   79638     7
# 4            4  2022-05-06    5  32  남성   57388     8
# ..         ...         ...  ...  ..  ..     ...   ...
# 95          95  2022-12-19   96  29  남성   65745     5
# 96          96  2022-10-13   97  50  여성  135456     4
# 97          97  2022-04-23   98  76  남성   29016     3
# 98          98  2022-12-17   99  24  여성  135247     3
# 99          99  2022-06-16  100  73  여성   52018     0
#
# [100 rows x 7 columns]

# %% [markdown]
# ## 데이터 불러오기

# %%
# 판다스 부분에서 했었던 데이터 불러오기
# 앞에서 실습한 파일 : crime_list.csv 사용

crime_list = pd.read_csv("crime_list.csv")

crime_list
# Out:
#     Unnamed: 0          날짜   ID  나이  성별      소득  범죄건수
# 0            0  2022-11-24    1  71  여성  141440     5
# 1            1  2022-02-27    2  67  남성  122769     4
# 2            2  2022-01-13    3  67  남성  122908     2
# 3            3  2022-05-21    4  21  여성   79638     7
# 4            4  2022-05-06    5  32  남성   57388     8
# ..         ...         ...  ...  ..  ..     ...   ...
# 95          95  2022-12-19   96  29  남성   65745     5
# 96          96  2022-10-13   97  50  여성  135456     4
# 97          97  2022-04-23   98  76  남성   29016     3
# 98          98  2022-12-17   99  24  여성  135247     3
# 99          99  2022-06-16  100  73  여성   52018     0
#
# [100 rows x 7 columns]

# %% [markdown]
# ## 시각화

# %%
# 상관분석에 앞서 먼저 시각화를 이용하여 상관성을 육안으로 확인해본다.
# 각 데이터의 히스토그램과 산점도를 도출(산점도에는 회귀선까지 구현)
sns.pairplot(crime_list, kind='reg')
plt.show()

# %% [markdown]
# ## 피어슨 상관 계수

# %%
# 하나씩 시행해보기
# 변수 지정, 소득과 범죄건수
x1 = crime_list['나이']
x2 = crime_list['범죄건수']

# 만약 표본상관계수를 도출하게 된다면 (n-1로 또 나눠주어야 함)
# mu = mean (공통적으로 적용)
mu_1 = np.sum(x1)/len(x1)
mu_2 = np.sum(x2)/len(x2)
# 분산을 구하는 부분에서도 모분산 추정이므로 자유도 1 설정
var_1 = np.sum([pow(i - mu_1, 2) for i in x1]) / (len(x1) - 1)
var_2 = np.sum([pow(i - mu_2, 2) for i in x2]) / (len(x2) - 1)
std_1 = var_1 ** 0.5
std_2 = var_2 ** 0.5

covariance_ddof = sum( (x1 - mu_1) * (x2 - mu_2) ) / (len(x1) -1)
correlation_ddof = covariance_ddof / (std_1 * std_2)

# COV(X,Y) : 표본인 경우 (numpy와 비교)
print(covariance_ddof)
print(np.cov(x1,x2))
# 피어슨 상관계수
print(correlation_ddof)
# Out:
# -12.521818181818178
# [[335.82414141 -12.52181818]
#  [-12.52181818   9.92767677]]
# -0.21686407922793227

# %% [markdown]
# ## scipy라이브러리를 활용

# %%
# 피어슨 상관계수를 구하는 다른 방법으로는 scipy라이브러리를 활용하는 법

from scipy.stats import pearsonr

# 귀무가설은 '두 데이터의 상관 계수가 0이다.(독립)'로 설정되어 있음.
pearsonr(x1, x2)

# 유의확률(p-value) 값이  유의수준(0.05)보다 작으면 귀무가설 기각- 대립가설 채택
# Out:
# PearsonRResult(statistic=-0.21686407922793235, pvalue=0.030216768642266308)

# %%
# 결과 해석 :

# %%
def cov_pearson(data1, data2, population = True):
    # 라이브러리 호출
    import numpy as np
    from scipy.stats import pearsonr

    # 변수를 설정하는 부분입니다.
    mu_1 = np.sum(data1)/len(data1)
    mu_2 = np.sum(data2)/len(data2)
    var_1 = np.sum([pow(i - mu_1, 2) for i in data1]) / (len(data1))
    var_2 = np.sum([pow(i - mu_2, 2) for i in data2]) / (len(data2))
    std_1 = var_1 ** 0.5
    std_2 = var_2 ** 0.5
    
    # 데이터가 모수인지 표본인지에 따라 자유도를 산입할지 여부를 결정합니다.
    if population == True:
        covariance = sum( (data1 - mu_1) * (data2 - mu_2) ) / (len(data1))
        correlation = covariance / (std_1 * std_2)
        print(f'모집단 data 각각의 분산 값은 COV(X,X) = {round(var_1,3)}, COV(Y,Y) = {round(var_2,3)}(으)로 계산됩니다.')
        print(f'모집단 data에 대한 공분산 값 : {round(covariance,3)}')
        print(f'모집단 data에 대한 피어슨 상관계수 값 : {round(correlation,3)}')
    else:
        var_1 = np.sum([pow(i - mu_1, 2) for i in data1]) / (len(data1) - 1)
        var_2 = np.sum([pow(i - mu_2, 2) for i in data2]) / (len(data2) - 1)
        std_1 = var_1 ** 0.5
        std_2 = var_2 ** 0.5
        covariance_ddof = sum( (data1 - mu_1) * (data2 - mu_2) ) / (len(data1) -1)
        correlation_ddof = covariance_ddof / (std_1 * std_2)
        print(f'표본 data 각각의 추정된 분산 값은 COV(x,x) = {round(var_1,3)}, COV(y,y) = {round(var_2,3)}(으)로 계산됩니다.')
        print(f'표본 data로 추정한 모집단의 공분산 값 : {round(covariance_ddof,3)}')
        print(f'표본 data로 추정한 모집단의 피어슨 상관계수 값 : {round(correlation_ddof,3)}')

    # Scipy 라이브러리에서 구한 피어슨 계수를 통해 위에서 확인한 상관계수 값을 검증해봅니다.
    print(f'Scipy로 구한 피어슨 상관계수는 {round(pearsonr(data1, data2)[0], 3)}입니다.')
    
    # Scipy에서 제공하는 피어슨 검정의 P값을 이용하여 데이터 간의 독립성에 대한 검정 결과 해석을 출력합니다.
    if pearsonr(data1, data2)[1] < 0.05:
        print(f'Scipy는 각 데이터의 상관계수가 유의한지 판단합니다. 위 검정의 p-value는 {round(pearsonr(data1, data2)[1],5) * 100}%로 두 데이터의 연관성이 없다는 귀무가설을 5%의 유의수준으로 기각할 수 있습니다.')
    else:
        print(f'Scipy는 각 데이터의 상관계수가 유의한지 판단합니다. 위 검정의 p-value는 {round(pearsonr(data1, data2)[1],5) * 100}%로 두 데이터의 연관성이 없다는 귀무가설을 5%의 유의수준으로 기각할 수 없습니다.')

print('1. 모집단으로 가정한 경우')
cov_pearson(x1, x2, True)

print('\n2. 표본집단으로 가정한 경우')
cov_pearson(x1, x2, False)
# Out:
# 1. 모집단으로 가정한 경우
# 모집단 data 각각의 분산 값은 COV(X,X) = 332.466, COV(Y,Y) = 9.828(으)로 계산됩니다.
# 모집단 data에 대한 공분산 값 : -12.397
# 모집단 data에 대한 피어슨 상관계수 값 : -0.217
# Scipy로 구한 피어슨 상관계수는 -0.217입니다.
# Scipy는 각 데이터의 상관계수가 유의한지 판단합니다. 위 검정의 p-value는 3.0220000000000002%로 두 데이터의 연관성이 없다는 귀무가설을 5%의 유의수준으로 기각할 수 있습니다.
#
# 2. 표본집단으로 가정한 경우
# 표본 data 각각의 추정된 분산 값은 COV(x,x) = 335.824, COV(y,y) = 9.928(으)로 계산됩니다.
# 표본 data로 추정한 모집단의 공분산 값 : -12.522
# 표본 data로 추정한 모집단의 피어슨 상관계수 값 : -0.217
# Scipy로 구한 피어슨 상관계수는 -0.217입니다.
# Scipy는 각 데이터의 상관계수가 유의한지 판단합니다. 위 검정의 p-value는 3.0220000000000002%로 두 데이터의 연관성이 없다는 귀무가설을 5%의 유의수준으로 기각할 수 있습니다.

# %% [markdown]
# # 범죄데이터 실습2 : 깃허브,  범죄데이터.csv

# %%
df = pd.read_csv("범죄데이터.csv",index_col=0)
df

# %%
# 컬럼명 :  한글 로 변경 
df.columns =  ['사건 번호', '날짜','블록','IUCR','범죄 유형','설명','위치 설명','검거 여부','가정 내 범죄','경찰서 순번','지구','구','지역 번호','FBI 코드','X 좌표','Y 좌표','년도','업데이트 일자','위도','경도','위치']

# %%
#### 스피어만 상관계수를 비교하기 위한 인코딩 작업

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(df["범죄 유형"])
df["범죄 유형"] = encoder.transform(df["범죄 유형"])

# %%
encoder = LabelEncoder()
encoder.fit(df["위치 설명"])
df["위치 설명"] = encoder.transform(df["위치 설명"])

# %%
encoder = LabelEncoder()
encoder.fit(df["설명"])
df["설명"] = encoder.transform(df["설명"])

# %%
# 상관계수를 확인하기 위한 컬럼 선택 : 숫자 데이터만
df_cor = df[['범죄 유형', '설명', '위치 설명', '검거 여부', '가정 내 범죄', '위도', '경도']]
df_cor.corr('spearman')

# %%
correlation_matrix = df_cor.corr()
plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, mask=mask,annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5,vmin=-1, vmax=1)
plt.title('상관계수 히트맵')
plt.show()

# %% [markdown]
# # 숫자형 만 상관계수 구하기(사례)

# %%
# 데이터 프레임에 문자열리 있는 경우에 숫자에 대하여만 상관계수 구하기

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset("titanic")

# %% [markdown]
# ## 데이터 탐색

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# 데이터 섹 탐색
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## 상관계수 구하기(숫자형 데이터 만)

# %%
# 숫자형 데이터만 선택 (int와 float 타입의 열만 선택)
df_numeric = df.select_dtypes(include=['number'])

# 상관계수 계산
correlation_matrix = df_numeric.corr()

# 결과 출력
print(correlation_matrix)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(df_numeric.corr(), annot=True)
# Out:
# <Axes: >

# %%
# 옵션 주기 : 제목 달기
sns.heatmap(df_numeric.corr(), annot=True)
plt.title('선박사고 생존자 상관관계')
# Out:
# Text(0.5, 1.0, '선박사고 생존자 상관관계')

# %% [markdown]
# ## 추가 : 상관계수 사례

# %%
import numpy as np
import matplotlib.pyplot as plt

# 예시 리스트 데이터
income = [50000000, 35000000, 83000000, 90000000, 150000000]
crime = [8, 6, 3, 2, 1]

# 피어슨 상관계수 계산 및 출력
correlation_matrix = np.corrcoef(income, crime)
pearson_coefficient = correlation_matrix[0, 1]
print(f"\nPearson Correlation Coefficient: {pearson_coefficient}")

# 산점도 그리기
plt.scatter(income, crime)
plt.xlabel('Income ')
plt.ylabel('Crime')
plt.title('Income vs Crime Scatter Plot')
plt.show()
# Out:
# Pearson Correlation Coefficient: -0.8536282482171071
